# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.11.0-cp312-cp312-win_amd64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl.metadata (121 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: numpy>=1.25 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.11.0-cp312-cp312-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/9.3 MB 6.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.4/9.3 MB 6.4 MB/s eta 0:00:02
#    -------------- ------------------------- 3.4/9.3 MB 6.1 MB/s eta 0:00:01
#    -------------------- ------------------- 4.7/9.3 MB 5.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.5/9.3 MB 5.5 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.6/9.3 MB 5.3 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.3 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.1/9.3 MB 4.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.4/9.3 MB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 4.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.9/9.3 MB 4.4 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 3.4 MB/s  0:00:02
# Downloading contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.63.0-cp312-cp312-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.3 MB 1.3 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.0/2.3 MB 1.5 MB/s eta 0:00:01
#    -------------------------- ------------- 1.6/2.3 MB 1.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.1/2.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.8 MB/s  0:00:01
# Downloading kiwisolver-1.5.0-cp312-cp312-win_amd64.whl (73 kB)
# Downloading pillow-12.2.0-cp312-cp312-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.1 MB 1.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.1 MB 1.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/7.1 MB 1.9 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/7.1 MB 1.5 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.1 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.1 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.1 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.1 MB 1.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.1/7.1 MB 1.1 MB/s eta 0:00:05
#    ------------- -------------------------- 2.4/7.1 MB 1.0 MB/s eta 0:00:05
#    -------------- ------------------------- 2.6/7.1 MB 1.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 2.9/7.1 MB 1.0 MB/s eta 0:00:05
#    ----------------- ---------------------- 3.1/7.1 MB 1.1 MB/s eta 0:00:04
#    -------------------- ------------------- 3.7/7.1 MB 1.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.9/7.1 MB 1.2 MB/s eta 0:00:03
#    ------------------------- -------------- 4.5/7.1 MB 1.3 MB/s eta 0:00:03
#    ---------------------------- ----------- 5.0/7.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 5.8/7.1 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 1.6 MB/s  0:00:04
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 pillow-12.2.0 pyparsing-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]

# %%
y=[10,20,25,30]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)

# %%
plt.show()

# %%
plt.plot(x,y,color='green',linestyle='--',marker='o')

# %%
plt.title('my plot')
# Out:
# Text(0.5, 1.0, 'my plot')

# %%
plt.xlabel('x-axis')
# Out:
# Text(0.5, 0, 'x-axis')

# %%
plt.ylabel('y-axis')
# Out:
# Text(0, 0.5, 'y-axis')

# %%
x =[1,2,3]

# %%
y1=[1,4,9]

# %%
y2=[1,4,9]

# %%
plt.plot(x,y1,label='squares')

# %%
plt.plot(x,y2,label='linear')

# %%
plt.legend()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16472\4061938096.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.show()

# %%
categories = ['a','b','c']

# %%
values = [5,7,3]

# %%
plt.bar(categories,values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.show()

# %%
data=[1,1,2,3,3,3,4,4,5]

# %%
plt.hist(data,bins=5)
# Out:
# (array([2., 1., 3., 2., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.show()

# %%
x=[1,2,3,4]

# %%
y=[10,20,25,30]

# %%
plt.scatter(x,y)

# %%
plt.show()

# %%
plt.subplot(1,2,1)
# Out:
# <Axes: >

# %%
plt.plot([1,2,3],[1,2,3])

# %%
plt.subplot(1,2,2)
# Out:
# <Axes: >

# %%
plt.plot([1,2,3],[3,2,1])

# %%
plt.show()

# %%
plt.plot(x,y)

# %%
plt.savefig('plot.png')
