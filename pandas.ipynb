# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=1.26.0 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in .\AppData\Local\Programs\Python\Python312\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = {'name':['alice','bob'],'age':[25,30]}

# %%
df = pd.DataFrame(data)

# %%
last =[['alice',25],['bob',30]]

# %%
df.head()
# Out:
#     name  age
# 0  alice   25
# 1    bob   30

# %%
df.tail()
# Out:
#     name  age
# 0  alice   25
# 1    bob   30

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2 non-null      str
#  1   age     2 non-null      int64
# dtypes: int64(1), str(1)
# memory usage: 164.0 bytes

# %%
df.describe()
# Out:
#              age
# count   2.000000
# mean   27.500000
# std     3.535534
# min    25.000000
# 25%    26.250000
# 50%    27.500000
# 75%    28.750000
# max    30.000000

# %%
df['name']
# Out:
# 0    alice
# 1      bob
# Name: name, dtype: str

# %%
df[['name','age']]
# Out:
#     name  age
# 0  alice   25
# 1    bob   30

# %%
df.loc[0]
# Out:
# name    alice
# age        25
# Name: 0, dtype: object

# %%
df.iloc[1]
# Out:
# name    bob
# age      30
# Name: 1, dtype: object

# %%
df[df['age']>25]
# Out:
#   name  age
# 1  bob   30

# %%
df['gender'] = ['f','m']

# %%
df.drop('age',axis=1,inplace=True)

# %%
df.isnull()
# Out:
#     name  gender
# 0  False   False
# 1  False   False

# %%
df.dropna()
# Out:
#     name gender
# 0  alice      f
# 1    bob      m

# %%
df.fillna(0)
# Out:
#     name gender
# 0  alice      f
# 1    bob      m

# %%
df1 = pd.DataFrame({'key':['A','B','C'],'value1':[1,2,3]})
df2=pd.DataFrame({'key':['A','B','D'],'value2':[4,5,6]})

# %%
pd.merge(df1,df2,on='key')
# Out:
#   key  value1  value2
# 0   A       1       4
# 1   B       2       5

# %%
df1.join(df2,lsuffix='_left',rsuffix='_right')
# Out:
#   key_left  value1 key_right  value2
# 0        A       1         A       4
# 1        B       2         B       5
# 2        C       3         D       6

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User'

# %%
os.listdir()
# Out:
# ['.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.vscode',
#  '.vscode-shared',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{fdb70ad5-e0ea-11ef-bc41-cc6b1e8404b8}.TM.blf',
#  'NTUSER.DAT{fdb70ad5-e0ea-11ef-bc41-cc6b1e8404b8}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{fdb70ad5-e0ea-11ef-bc41-cc6b1e8404b8}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'Recent',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Start Menu',
#  'Templates',
#  'Untitled.ipynb',
#  'Videos']

# %%
df = pd.read_csv('data.csv')

# %%
df.to_csv('output.csv',index=False)

# %%
df.sort_values('age')
# Out:
#     name  age
# 0  Alice   25
# 1    Bob   30

# %%
df['age'].apply(lambda x: x+1)
# Out:
# 0    26
# 1    31
# Name: age, dtype: int64

# %%
df['name'].unique()
# Out:
# <StringArray>
# ['Alice', 'Bob']
# Length: 2, dtype: str

# %%
df['age'].value_counts()
# Out:
# age
# 25    1
# 30    1
# Name: count, dtype: int64
